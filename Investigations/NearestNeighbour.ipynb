# %%
import geopandas as gpd
import pickle
from sklearn.neighbors import BallTree
import numpy as np
from shapely.geometry import LineString
# %matplotlib inline
import matplotlib.pyplot as plt

root_path = "D:/GeoData/"
Main_CRS = "EPSG:27700"

# %%
def load_obj(name ):
    with open(root_path + 'WorkingData/' + name + '.pkl', 'rb') as f:
        return pickle.load(f)

# %%
Mapset = load_obj("Clipped5k_South_London")

# %%
fig, axes=plt.subplots(nrows=1, ncols=2, figsize=(20,10))
#Plot postcodes
Mapset['NSPL_gdf'].plot(ax=axes[0],markersize=0.5, alpha=0.5)
axes[0].set_title('Postcodes')

#Plot Train Stations
Mapset['RailwayStations'].plot(ax=axes[1], markersize=5, alpha=0.5, color='red')
axes[1].set_title('Train Stations');

# %%
def get_nearest(src_points, candidates, k_neighbors=1):
    """Find nearest neighbors for all source points from a set of candidate points"""

    # Create tree from the candidate points
     # removed metric since the default is euclidian (what my coordinates use)
    tree = BallTree(candidates, leaf_size=15)

    # Find closest points and distances
    distances, indices = tree.query(src_points, k=k_neighbors)

    # Transpose to get distances and indices into arrays
    distances = distances.transpose()
    indices = indices.transpose()

    # Get closest indices and distances (i.e. array at index 0)
    # note: for the second closest points, you would take index 1, etc.
    closest = indices[0]
    closest_dist = distances[0]

    # Return indices and distances
    return (closest, closest_dist)

# %%
def nearest_neighbor(left_gdf, right_gdf, right_col_name, outname, return_dist=False):
    """
    For each point in left_gdf, find closest point in right GeoDataFrame and return them.
    """

    left_geom_col = left_gdf.geometry.name
    right_geom_col = right_gdf.geometry.name

    # Ensure that index in right gdf is formed of sequential numbers
    left = left_gdf.copy().reset_index(drop=True)
    right = right_gdf.copy().reset_index(drop=True)
    
    left_points = np.array(left[left_geom_col].apply(lambda geom: (geom.x, geom.y)).to_list())
    right_points = np.array(right[right_geom_col].apply(lambda geom: (geom.x, geom.y)).to_list())

    # Find the nearest points
    # -----------------------
    # closest ==> index in right_gdf that corresponds to the closest point
    # dist ==> distance between the nearest neighbors (in meters)

    closest, dist = get_nearest(src_points=left_points, candidates=right_points)

    # Return points from right GeoDataFrame that are closest to points in left GeoDataFrame
    closest_points = right.loc[closest]

    # Ensure that the index corresponds the one in left_gdf
    left_index = left_gdf.index
    closest_points = closest_points.reset_index(drop=True)
    print(closest_points)
    closest_points = closest_points.set_index(left_index)
    
    #Select the columns to keep in the output dataframe
    keep = [right_col_name, 'geometry']
    closest_points = closest_points[keep]
    
    suffix = "Nearest_" + outname
    
    closest_points = closest_points.rename(columns={right_col_name: suffix + '_Name'})
    closest_points = closest_points.rename(columns={'geometry': suffix + '_geometry'})
    
    # Add distance if requested
    if return_dist:
        closest_points[suffix + '_distance'] = dist

    return closest_points

# %%
Nearest_TrainStation = nearest_neighbor(Mapset['NSPL_gdf'], 
                                        Mapset['RailwayStations'], 
                                        "StationName", 
                                        "TrainStation", 
                                        return_dist=True)

# And the result looks like ..
Nearest_TrainStation
# Out:
#      TiplocCode CrsCode                      StationName  Easting  Northing  \
# 0       CLOCKHS     CLK         Clock House Rail Station   536370    169550
# 1       CLOCKHS     CLK         Clock House Rail Station   536370    169550
# 2       BCKNHMJ     BKJ  Beckenham Junction Rail Station   537395    169850
# 3       BCKNHMJ     BKJ  Beckenham Junction Rail Station   537395    169850
# 4       BCKNHMJ     BKJ  Beckenham Junction Rail Station   537395    169850
# ...         ...     ...                              ...      ...       ...
# 5710    CATFBDG     CFB      Catford Bridge Rail Station   537365    173600
# 5711    CATFBDG     CFB      Catford Bridge Rail Station   537365    173600
# 5712    CATFBDG     CFB      Catford Bridge Rail Station   537365    173600
# 5713    CATFBDG     CFB      Catford Bridge Rail Station   537365    173600
# 5714    BELNGHM     BGM          Bellingham Rail Station   537780    172295
#
#                            geometry
# 0     POINT (536370.000 169550.000)
# 1     POINT (536370.000 169550.000)
# 2     POINT (537395.000 169850.000)
# 3     POINT (537395.000 169850.000)
# 4     POINT (537395.000 169850.000)
# ...                             ...
# 5710  POINT (537365.000 173600.000)
# 5711  POINT (537365.000 173600.000)
# 5712  POINT (537365.000 173600.000)
# 5713  POINT (537365.000 173600.000)
# 5714  POINT (537780.000 172295.000)
#
# [5715 rows x 6 columns]
#                Nearest_TrainStation_Name  Nearest_TrainStation_geometry  \
# 248537          Clock House Rail Station  POINT (536370.000 169550.000)
# 248538          Clock House Rail Station  POINT (536370.000 169550.000)
# 248539   Beckenham Junction Rail Station  POINT (537395.000 169850.000)
# 248540   Beckenham Junction Rail Station  POINT (537395.000 169850.000)
# 248541   Beckenham Junction Rail Station  POINT (537395.000 169850.000)
# ...                                  ...                            ...
# 2069194      Catford Bridge Rail Station  POINT (537365.000 173600.000)
# 2069195      Catford Bridge Rail Station  POINT (537365.000 173600.000)
# 2069196      Catford Bridge Rail Station  POINT (537365.000 173600.000)
# 2069197      Catford Bridge Rail Station  POINT (537365.000 173600.000)
# 2069198          Bellingham Rail Station  POINT (537780.000 172295.000)
#
#          Nearest_TrainStation_distance
# 248537                      584.216569
# 248538                      633.089251
# 248539                      624.119380
# 248540                      568.989455
# 248541                      557.210912
# ...                                ...
# 2069194                     279.644417
# 2069195                     279.644417
# 2069196                     279.644417
# 2069197                     279.644417
# 2069198                     607.870052
#
# [5715 rows x 3 columns]

# %%
# Merge the datasets by index (for this, it is good to use '.join()' -function)
Mapset['NSPL_gdf'] = Mapset['NSPL_gdf'].join(Nearest_TrainStation)

# %%
# Create a link (LineString) between building and stop points
Mapset['NSPL_gdf']['link'] = Mapset['NSPL_gdf'].apply(lambda row: LineString([row['geometry'], row['Nearest_TrainStation_Geometry']]), axis=1)

# Set link as the active geometry
Postcode_links = Mapset['NSPL_gdf'].copy()
Postcode_links = Postcode_links.set_geometry('link')

# Plot the connecting links between buildings and stops and color them based on distance
ax = Postcode_links.plot(column='Nearest_TrainStation_Distance', cmap='Greens', scheme='quantiles', k=4, alpha=0.8, lw=0.7, figsize=(13, 10))
ax = Mapset['NSPL_gdf'].plot(ax=ax, color='yellow', markersize=1, alpha=0.7)
ax = Mapset['RailwayStations'].plot(ax=ax, markersize=4, marker='o', color='red', alpha=0.9, zorder=3)

# Set map background color to black, which helps with contrast
ax.set_facecolor('black')

plt.savefig("Images/" + 'NearestNeighbour.png',dpi=300)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\LandReg_py\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\Anaconda3\envs\LandReg_py\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\Anaconda3\envs\LandReg_py\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Nearest_TrainStation_Geometry'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14880/2182397631.py in <module>
#       1 # Create a link (LineString) between building and stop points
# ----> 2 Mapset['NSPL_gdf']['link'] = Mapset['NSPL_gdf'].apply(lambda row: LineString([row['geometry'], row['Nearest_TrainStation_Geometry']]), axis=1)
#       3
#       4 # Set link as the active geometry
#       5 Postcode_links = Mapset['NSPL_gdf'].copy()
#
# ~\Anaconda3\envs\LandReg_py\lib\site-packages\geopandas\geodataframe.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    1359     @inherit_doc(pd.DataFrame)
#    1360     def apply(self, func, axis=0, raw=False, result_type=None, args=(), **kwargs):
# -> 1361         result = super().apply(
#    1362             func, axis=axis, raw=raw, result_type=result_type, args=args, **kwargs
#    1363         )
#
# ~\Anaconda3\envs\LandReg_py\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8738             kwargs=kwargs,
#    8739         )
# -> 8740         return op.apply()
#    8741
#    8742     def applymap(
#
# ~\Anaconda3\envs\LandReg_py\lib\site-packages\pandas\core\apply.py in apply(self)
#     686             return self.apply_raw()
#     687
# --> 688         return self.apply_standard()
#     689
#     690     def agg(self):
#
# ~\Anaconda3\envs\LandReg_py\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     810
#     811     def apply_standard(self):
# --> 812         results, res_index = self.apply_series_generator()
#     813
#     814         # wrap results
#
# ~\Anaconda3\envs\LandReg_py\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     826             for i, v in enumerate(series_gen):
#     827                 # ignore SettingWithCopy here in case the user mutates
# --> 828                 results[i] = self.f(v)
#     829                 if isinstance(results[i], ABCSeries):
#     830                     # If we have a view on v, we need to make a copy because
#
# ~\AppData\Local\Temp/ipykernel_14880/2182397631.py in <lambda>(row)
#       1 # Create a link (LineString) between building and stop points
# ----> 2 Mapset['NSPL_gdf']['link'] = Mapset['NSPL_gdf'].apply(lambda row: LineString([row['geometry'], row['Nearest_TrainStation_Geometry']]), axis=1)
#       3
#       4 # Set link as the active geometry
#       5 Postcode_links = Mapset['NSPL_gdf'].copy()
#
# ~\Anaconda3\envs\LandReg_py\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# ~\Anaconda3\envs\LandReg_py\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#    1049
#    1050         # Similar to Index.get_value, but we do not fall back to positional
# -> 1051         loc = self.index.get_loc(label)
#    1052         return self.index._get_values_for_loc(self, loc, label)
#    1053
#
# ~\Anaconda3\envs\LandReg_py\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Nearest_TrainStation_Geometry'

# %%
Nearest_BusStop = nearest_neighbor(Mapset['NSPL_gdf'], 
                                        Mapset['BusStops'], 
                                        "CommonName", 
                                        "BusStop", 
                                        return_dist=True)

Mapset['NSPL_gdf'] = Mapset['NSPL_gdf'].join(Nearest_BusStop)

# %%
All_Maps = load_obj("All_Maps")

# %%
import time
start = time.time()
Nearest_TrainStation = nearest_neighbor(All_Maps['NSPL_gdf'], 
                                        All_Maps['RailwayStations'], 
                                        "StationName", 
                                        "TrainStation", 
                                        return_dist=True)
end = time.time()
Elapsed_Time = end - start
Elapsed_Time
